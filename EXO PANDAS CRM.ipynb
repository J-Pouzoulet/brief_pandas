# %%
'''CRM_data.csv est un fichier csv qui contient de vraies données CRM d'une entreprise.
L'idée de ce sujet est de vérifier si les données sont clean et de produire dans un second temps une analyse des
données présents dans le dataset.

Contexte:
Il s'agit d'un extrait des leads gagnés et perdus sur une période de 3 mois environ.

Définitions:
- Lead: Un utilisateur qui s'inscrit sur le site de l'entreprise
- Taux de conversion: Nombre de Leads gagnés sur nombre de leads inscrits

Description des données:
- Subscribe date: date d'inscription du lead sur notre site
- Stagename: Etape actuelle du dossier client dans la base (Ici on ne garde uniquement les dossiers gagnés ou perdus)
- Project type: type de projet d'achat: achat d'une résidence principale, d'une résidence secondaire
		    ou bien d'un investissement locatif
- Property kind: Type de bien: ancien, nouveau, VEFA, terrain
- Source of lead: Canal Marketing source du lead (par exemple pub Google, pub Facebook, partenariat ...)
- Amount: Montant du projet (gain si le projet est gagné)
- Lost reason: Raison pour laquelle le dossier a été perdu (si perdu)
- Lost date: Date de perte du dossier (si perdu)
- Won (indicateurs des dossiers gagnés)
- Coût du lead: Coût du lead. (si pas de coût, il s'agit d'un lead gratuit: une personne qui vient directement sur le site)


Questions Préliminaires:
1. Décrire les colonnes du dataset


2. Donner la proportions de valeurs manquantes pour chaque colonne
3. Compter le nombre de valeurs uniques pour chaque colonne
4. Donner ces valeurs
5. Convertir les 2 colonnes associées à une date au format date de Python
6. Créer une nouvelle colonne 'Stagename_bin' qui sera formée de valeurs égales à 0 si Perdu, 1 si gagné
6bis. Créer une 3ème colonne en appliquant la méthode 'get_dummies()' 
7. Combien y-a-t-il de leads gagnés dans ce dataset ?
8. Faire la même chose que les 2 colonnes précédentes pour la colonne Project type
9. Renommer les colonnes 'Lost reason' et 'Source of lead' en 'Lost_reason' et 'Source_of_lead'
10. Grouper toutes les lignes en fonction 'Source_of_lead'. Lors du groupement, ne conserver que la somme de amount
11. Créer une colonne intitulée 'total' qui correspond à la somme de 'Gagné' et 'Perdu'. A quoi est égale cette colonne
12. Supprimer la dernière colonne créée vu qu'elle est inutile
13. Pour la colonne 'Lost_reason', lorsque c'est le cas, remplacer '/' par '-'
14. Remplacer les élément NaN de la colonne 'Property kind' par 'other'


Questions:
1. Quel est le montant moyen des inscriptions par mois ?
2. Calculer l'évolution du taux de conversion par jour. On s'attend à avoir un groupement par mois et par jour et un taux de conversion
2bis. Tracer la courbe du taux de conversion en fonction du temps 
3. Quelles sont les principales raisons de pertes des dossiers (Colonne: "Lost Reason"). A vous de définir comment faire... (Il y a plusieurs façons d'y parvenir)
4. Le directeur marketing souhaite retravailler la répartition de sonbudget par canal. Quelles recommandations feriez-vous
sur les canaux à prioriser
5. Pensez-vous à des indicateurs ou graphes non réalisés plus hauts qui seraient utiles à réaliser pour mieux
comprendre le sujet ? (les réaliser)
6. Au vu des questions posées dans la rubrique question, aurait-il été intéressant de supprimer les lignes pour lesquelles 'Cout du lead' = np.nan ?
7. Est-il pertinent de remplacer les éléments NaN de la colonne 'Won' par 0 ? Si oui, le faire sinon laisser tel quel'''

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CRM_data.csv')

# %%
df
# Out:
#      Subscribe date Stagename       Project type Property kind Source of lead  \
# 0        2019-02-25     Gagné  primary_residence           old       partner1
# 1        2019-02-26     Perdu  primary_residence           new       partner1
# 2        2019-01-09     Perdu  primary_residence           NaN       partner1
# 3        2019-03-22     Perdu  primary_residence           new       partner1
# 4        2019-03-03     Gagné  rental_investment           old       partner1
# ...             ...       ...                ...           ...            ...
# 3601     2019-01-26     Perdu  rental_investment           NaN            NaN
# 3602     2019-01-03     Gagné  primary_residence           old            NaN
# 3603     2019-03-06     Perdu  rental_investment           old            NaN
# 3604     2019-02-14     Perdu  primary_residence           old            NaN
# 3605     2019-01-22     Perdu  primary_residence           NaN            NaN
#
#       Amount                            Lost reason   Lost date  Won  \
# 0        118                                    NaN         NaN  1.0
# 1        184         N'a jamais répondu (+5 appels)  2019-03-13  NaN
# 2        243         N'a jamais répondu (+5 appels)         NaN  NaN
# 3        215  Projet en recherche / Projet lointain  2019-03-28  NaN
# 4        142                                    NaN         NaN  1.0
# ...      ...                                    ...         ...  ...
# 3601     196              Perdu contre autre banque         NaN  NaN
# 3602      59                                    NaN         NaN  1.0
# 3603     242  Projet en recherche / Projet lointain  2019-03-15  NaN
# 3604     112       Ne souhaite pas faire ce dossier  2019-04-01  NaN
# 3605     140         N'a jamais répondu (+5 appels)         NaN  NaN
#
#       Cout du lead
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 3601           NaN
# 3602           NaN
# 3603           NaN
# 3604           NaN
# 3605           NaN
#
# [3606 rows x 10 columns]

# %%
dict_descript = {}

# %%
dict_descript
# Out:
# {}

# %%
list_col_names = list(df.columns)

# %%
list_col_names
# Out:
# ['Subscribe date',
#  'Stagename',
#  'Project type',
#  'Property kind',
#  'Source of lead',
#  'Amount',
#  'Lost reason',
#  'Lost date',
#  'Won',
#  'Cout du lead']

# %%
for i in list_col_names:
    dict_descript[i] = list(pd.unique(df[i]))

# %%
for i in dict_descript:
    print(i, dict_descript[i])
# Out:
# Subscribe date ['2019-02-25', '2019-02-26', '2019-01-09', '2019-03-22', '2019-03-03', '2019-03-09', '2019-03-21', '2019-03-27', '2019-02-07', '2019-01-05', '2019-01-17', '2019-02-11', '2019-01-08', '2019-01-12', '2019-01-20', '2019-01-02', '2019-01-04', '2019-02-16', '2019-01-19', '2019-02-22', '2019-02-09', '2019-02-21', '2019-02-28', '2019-03-28', '2019-03-23', '2019-02-27', '2019-01-16', '2019-02-08', '2019-02-20', '2019-02-13', '2019-02-17', '2019-02-03', '2019-02-01', '2019-01-06', '2019-01-27', '2019-01-26', '2019-01-07', '2019-01-23', '2019-01-14', '2019-02-10', '2019-03-26', '2019-03-05', '2019-01-03', '2019-01-13', '2019-02-18', '2019-01-01', '2019-03-25', '2019-03-14', '2019-03-07', '2019-03-01', '2019-03-04', '2019-03-13', '2019-03-20', '2019-03-19', '2019-03-29', '2019-01-30', '2019-01-15', '2019-03-18', '2019-01-11', '2019-01-29', '2019-03-06', '2019-01-10', '2019-02-06', '2019-02-15', '2019-02-02', '2019-03-11', '2019-03-08', '2019-03-15', '2019-03-02', '2019-03-16', '2019-03-10', '2019-03-17', '2019-03-12', '2019-02-05', '2019-01-31', '2019-02-14', '2019-01-25', '2019-03-24', '2019-01-18', '2019-01-24', '2019-02-23', '2019-02-24', '2019-02-19', '2019-01-28', '2019-02-04', '2019-01-21', '2019-02-12', '2019-01-22']
# Stagename ['Gagné', 'Perdu']
# Project type ['primary_residence', 'rental_investment', 'secondary_residence', nan]
# Property kind ['old', 'new', nan, 'VEFA', 'land_construction', 'construction']
# Source of lead ['partner1', 'partner10', 'partner2', 'partner3', 'partner4', 'partner5', 'partner6', 'partner7', 'partner8', 'partner9', nan]
# Amount [118, 184, 243, 215, 142, 246, 77, 162, 60, 108, 123, 205, 127, 111, 153, 226, 141, 62, 69, 200, 100, 89, 241, 55, 231, 211, 207, 181, 112, 107, 124, 242, 183, 125, 240, 103, 76, 157, 137, 175, 212, 84, 189, 199, 53, 185, 75, 208, 190, 159, 131, 166, 139, 169, 197, 163, 144, 121, 87, 220, 122, 85, 244, 224, 80, 249, 102, 235, 164, 209, 237, 104, 120, 61, 233, 276, 204, 188, 245, 272, 278, 174, 259, 285, 277, 228, 173, 81, 192, 58, 150, 152, 206, 147, 172, 67, 132, 213, 225, 171, 248, 221, 136, 135, 250, 219, 198, 54, 196, 179, 96, 138, 99, 129, 115, 52, 72, 229, 133, 74, 110, 178, 105, 66, 161, 155, 109, 146, 148, 232, 222, 97, 202, 151, 128, 216, 126, 247, 195, 88, 158, 90, 101, 201, 70, 64, 156, 140, 78, 193, 177, 236, 57, 217, 167, 63, 214, 149, 187, 68, 194, 93, 134, 176, 83, 65, 98, 230, 143, 218, 210, 180, 154, 117, 234, 182, 114, 51, 203, 168, 92, 91, 94, 160, 56, 71, 186, 227, 191, 95, 145, 50, 223, 59, 79, 73, 113, 119, 239, 170, 165, 116, 238, 130, 106, 82, 86]
# Lost reason [nan, "N'a jamais répondu (+5 appels)", 'Projet en recherche / Projet lointain', 'Ne souhaite pas faire ce dossier', 'Perdu contre autre banque', 'A répondu mais ne répond plus (+5 appels)', 'Test', 'Dossier non finançable', 'Projet arrêté', 'Faux email & numéro', 'Doublon', 'Perdu contre autre courtier', 'Client extrêmement difficile']
# Lost date [nan, '2019-03-13', '2019-03-28', '2019-05-06', '2019-04-24', '2019-05-02', '2019-06-12', '2019-03-20', '2019-03-29', '2019-08-01', '2019-05-18', '2019-03-22', '2019-04-04', '2019-03-06', '2019-03-05', '2019-03-26', '2019-04-23', '2019-08-28', '2019-04-29', '2019-08-30', '2019-09-09', '2019-04-17', '2019-05-20', '2019-09-19', '2019-06-18', '2019-09-05', '2019-06-25', '2019-04-05', '2019-04-02', '2019-06-27', '2019-06-04', '2019-06-24', '2019-07-24', '2019-06-13', '2019-05-31', '2019-05-15', '2019-05-28', '2019-04-13', '2019-05-10', '2019-07-23', '2019-04-09', '2019-06-06', '2019-05-03', '2019-05-09', '2019-09-17', '2019-07-12', '2019-10-03', '2019-04-01', '2019-05-16', '2019-07-03', '2019-05-22', '2019-03-16', '2019-09-12', '2019-03-08', '2019-04-03', '2019-04-16', '2019-03-15', '2019-03-14', '2019-03-27', '2019-05-17', '2019-04-26', '2019-04-20', '2019-03-25', '2019-09-23', '2019-04-12', '2019-06-22', '2019-03-18', '2019-03-19', '2019-05-29', '2019-03-09', '2019-06-21', '2019-03-07', '2019-04-11', '2019-03-11', '2019-03-12', '2019-06-26', '2019-05-13', '2019-04-08', '2019-04-18', '2019-04-15', '2019-09-18', '2019-09-24', '2019-06-19', '2019-09-06', '2019-03-30', '2019-03-21', '2019-05-24', '2019-04-19', '2019-04-10', '2019-05-14', '2019-07-22', '2019-07-05', '2019-08-05', '2019-09-11', '2019-07-15', '2019-09-25', '2019-10-02', '2019-06-03', '2019-07-17', '2019-07-09', '2019-07-10', '2019-03-04', '2019-09-26', '2019-05-21', '2019-08-27', '2019-02-11', '2019-04-30', '2019-07-19', '2019-09-04', '2019-08-06', '2019-06-11', '2019-09-02', '2019-07-08', '2019-05-23', '2019-08-12', '2019-07-16', '2019-05-27', '2019-05-25', '2019-09-10', '2019-04-25', '2019-09-03', '2019-06-20', '2019-06-17', '2019-10-04', '2019-07-01', '2019-09-16', '2019-06-05', '2019-07-31', '2019-08-13', '2019-07-04', '2019-07-11', '2019-08-19', '2019-06-15', '2019-07-18', '2019-10-01', '2019-06-14', '2019-07-02', '2019-09-13', '2019-05-07', '2019-08-23', '2019-06-08', '2019-08-21', '2019-03-23', '2019-08-02', '2019-08-22', '2019-08-26', '2019-08-08', '2019-06-07', '2019-08-07', '2019-08-24', '2019-08-09', '2019-06-10', '2019-04-14', '2019-04-06', '2019-09-30', '2019-06-01', '2019-05-04', '2019-08-14']
# Won [1.0, nan]
# Cout du lead [nan, 10.0, 33.0, 25.0, 28.0, 32.0, 34.0, 27.0, 30.0, 29.0, 31.0, 26.0, 35.0, 11.0, 16.0, 12.0, 20.0, 19.0, 17.0, 13.0, 14.0, 15.0, 18.0, 37.0, 23.0, 24.0, 5.0, 100.0]

# %%
df.describe()
# Out:
#             Amount    Won  Cout du lead
# count  3606.000000  368.0    834.000000
# mean    155.906267    1.0     15.828537
# std      57.456713    0.0     18.575904
# min      50.000000    1.0      5.000000
# 25%     108.000000    1.0      5.000000
# 50%     157.000000    1.0      5.000000
# 75%     205.000000    1.0     26.000000
# max     285.000000    1.0    100.000000

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=True)

# %%
df

# %%
(df.count()/df.shape[0] * 100)
# Out:
# Subscribe date    100.000000
# Stagename         100.000000
# Project type       99.833380
# Property kind      51.291308
# Source of lead     43.349070
# Amount            100.000000
# Lost reason        88.864204
# Lost date          51.124688
# Won                10.219384
# Cout du lead       23.132463
# dtype: float64

# %%
df['Lost date'] = pd.to_datetime(df['Lost date'])

# %%
type(df['Lost date'].iloc[102])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Subscribe date'] = pd.to_datetime(df['Subscribe date'])

# %%
df

# %%
df['Lost date']
# Out:
# 0             NaT
# 1      2019-03-13
# 2             NaT
# 3      2019-03-28
# 4             NaT
#           ...
# 3596          NaT
# 3597          NaT
# 3598   2019-03-15
# 3599   2019-04-01
# 3600          NaT
# Name: Lost date, Length: 3601, dtype: datetime64[ns]

# %%
df

# %%
Stagename_bin = df['Stagename'].apply(lambda x: 1 if x == 'Gagné' else 0)

# %%
df['Stagename_bin'] = Stagename_bin

# %%
df

# %%
df['Stagename_bin']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3596    0
# 3597    1
# 3598    0
# 3599    0
# 3600    0
# Name: Stagename_bin, Length: 3601, dtype: int64

# %%
df['Stagename_bin_dum'] = pd.get_dummies(df['Stagename'])['Gagné']

# %%
sum(df['Stagename_bin'])
# Out:
# 368

# %%
def funct(x):
    if x == 'primary_residence':
        return 1
    if x == 'rental_investment':
        return 2
    if x == 'secondary_residence':
        return 3
    if x == 'nan':
        return np.nan

# %%
df['Project_type_bin'] = df['Project type'].apply(lambda x: funct(x))

# %%
df.columns = ['Subscribe_date', 'Stagename', 'Project_type', 'Property_kind',
       'Source_of_lead', 'Amount', 'Lost_reason', 'Lost_date', 'Won',
       'Cout_du_lead', 'Stagename_bin', 'Stagename_bin_dum',
       'Project_type_bin']

# %%
df_g1 = df.grouby('Source_of_lead', )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2588/750830262.py in <module>
# ----> 1 df_g1 = df.grouby('Source_of_lead', )
#
# ~/.pyenv/versions/simplon/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'grouby'

# %%
df.groupby('Source_of_lead').sum()['Amount']
# Out:
# Source_of_lead
# partner1     13996
# partner10     4153
# partner2     34871
# partner3      7301
# partner4     65485
# partner5      3940
# partner6     23800
# partner7       690
# partner8      1935
# partner9     98810
# Name: Amount, dtype: int64

# %%
df['total'] = df['Amount'] - df['Cout_du_lead']

# %%
df.drop('total', inplace=True, axis=1)

# %%
type(df['Lost_reason'][12]) == type('')
# Out:
# True

# %%
df['Lost_reason'] = df['Lost_reason'].apply(lambda x: x.replace('/','-') if type(x) == type('') else x)

# %%
type(1.23)
# Out:
# float

# %%
df['Property_kind'] = df['Property_kind'].apply(lambda x: 'other' if type(x) == type(1.23) else x)

# %%
df['Subscribe_month'] = df['Subscribe_date'].dt.month

# %%
df.groupby('Subscribe_month').count()
# Out:
#                  Subscribe_date  Stagename  Project_type  Property_kind  \
# Subscribe_month
# 1                          1241       1241          1236           1241
# 2                          1236       1236          1235           1236
# 3                          1124       1124          1124           1124
#
#                  Source_of_lead  Amount  Lost_reason  Lost_date  Won  \
# Subscribe_month
# 1                           492    1241         1121        345  116
# 2                           476    1236         1097        548  122
# 3                           593    1124          982        948  130
#
#                  Cout_du_lead  Stagename_bin  Stagename_bin_dum  \
# Subscribe_month
# 1                         220           1241               1241
# 2                         217           1236               1236
# 3                         396           1124               1124
#
#                  Project_type_bin
# Subscribe_month
# 1                            1236
# 2                            1235
# 3                            1124

# %%
df
# Out:
#      Subscribe_date Stagename       Project_type Property_kind Source_of_lead  \
# 86       2019-01-01     Perdu  rental_investment         other       partner1
# 136      2019-01-01     Perdu  primary_residence         other       partner3
# 374      2019-01-01     Perdu  primary_residence         other       partner5
# 469      2019-01-01     Perdu  primary_residence         other       partner2
# 485      2019-01-01     Perdu  primary_residence         other       partner2
# ...             ...       ...                ...           ...            ...
# 3100     2019-03-29     Perdu  primary_residence           old            NaN
# 3201     2019-03-29     Perdu  primary_residence           old       partner4
# 3331     2019-03-29     Gagné  primary_residence           old            NaN
# 3563     2019-03-29     Perdu  primary_residence           old       partner6
# 3592     2019-03-29     Perdu  primary_residence          VEFA            NaN
#
#       Amount                                Lost_reason  Lost_date  Won  \
# 86       120           Ne souhaite pas faire ce dossier        NaT  NaN
# 136      221                Perdu contre autre courtier        NaT  NaN
# 374      219  A répondu mais ne répond plus (+5 appels)        NaT  NaN
# 469      115  A répondu mais ne répond plus (+5 appels)        NaT  NaN
# 485      123             N'a jamais répondu (+5 appels)        NaT  NaN
# ...      ...                                        ...        ...  ...
# 3100     199             N'a jamais répondu (+5 appels) 2019-06-06  NaN
# 3201     196             N'a jamais répondu (+5 appels) 2019-06-05  NaN
# 3331      94                                        NaN        NaT  1.0
# 3563      78                                       Test 2019-04-02  NaN
# 3592     207                  Perdu contre autre banque 2019-04-01  NaN
#
#       Cout_du_lead  Stagename_bin  Stagename_bin_dum  Project_type_bin  \
# 86             NaN              0                  0               2.0
# 136            NaN              0                  0               1.0
# 374           20.0              0                  0               1.0
# 469            NaN              0                  0               1.0
# 485            NaN              0                  0               1.0
# ...            ...            ...                ...               ...
# 3100           NaN              0                  0               1.0
# 3201           NaN              0                  0               1.0
# 3331           NaN              1                  1               1.0
# 3563           NaN              0                  0               1.0
# 3592           NaN              0                  0               1.0
#
#       Subscribe_month  Subscribe_day
# 86                  1              1
# 136                 1              1
# 374                 1              1
# 469                 1              1
# 485                 1              1
# ...               ...            ...
# 3100                3             29
# 3201                3             29
# 3331                3             29
# 3563                3             29
# 3592                3             29
#
# [3601 rows x 15 columns]

# %%
df['Subscribe_day'] = df['Subscribe_date'].dt.day

# %%
df_day = df.groupby('Subscribe_day').count()

# %%
df = df.sort_values(['Subscribe_month', 'Subscribe_day'],
              ascending = [True, True])

# %%
df_day = df.groupby(['Subscribe_month', 'Subscribe_day']).count()

# %%
df_day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2588/1292315224.py in <module>
# ----> 1 df_day
#
# NameError: name 'df_day' is not defined

# %%
df_day['Taux_conversion'] = df_day['Won'] /  df_day['Subscribe_date']

# %%
df_day
# Out:
#                                Subscribe_date  Stagename  Project_type  \
# Subscribe_month Subscribe_day
# 1               1                          20         20            20
#                 2                          53         53            52
#                 3                          53         53            53
#                 4                          47         47            46
#                 5                          50         50            49
# ...                                       ...        ...           ...
# 3               25                         60         60            60
#                 26                         37         37            37
#                 27                         32         32            32
#                 28                         40         40            40
#                 29                         33         33            33
#
#                                Property_kind  Source_of_lead  Amount  \
# Subscribe_month Subscribe_day
# 1               1                         20              12      20
#                 2                         53              18      53
#                 3                         53              18      53
#                 4                         47              20      47
#                 5                         50              22      50
# ...                                      ...             ...     ...
# 3               25                        60              31      60
#                 26                        37              13      37
#                 27                        32              21      32
#                 28                        40              22      40
#                 29                        33              19      33
#
#                                Lost_reason  Lost_date  Won  Cout_du_lead  \
# Subscribe_month Subscribe_day
# 1               1                       19          3    1             3
#                 2                       48          8    5             9
#                 3                       50          9    3             9
#                 4                       43          7    3             6
#                 5                       45         11    4             9
# ...                                    ...        ...  ...           ...
# 3               25                      52         49    8            22
#                 26                      33         31    4             6
#                 27                      28         27    5            15
#                 28                      37         35    3            14
#                 29                      28         27    5            15
#
#                                Stagename_bin  Stagename_bin_dum  \
# Subscribe_month Subscribe_day
# 1               1                         20                 20
#                 2                         53                 53
#                 3                         53                 53
#                 4                         47                 47
#                 5                         50                 50
# ...                                      ...                ...
# 3               25                        60                 60
#                 26                        37                 37
#                 27                        32                 32
#                 28                        40                 40
#                 29                        33                 33
#
#                                Project_type_bin  Taux_conversion
# Subscribe_month Subscribe_day
# 1               1                            20         0.050000
#                 2                            52         0.094340
#                 3                            53         0.056604
#                 4                            46         0.063830
#                 5                            49         0.080000
# ...                                         ...              ...
# 3               25                           60         0.133333
#                 26                           37         0.108108
#                 27                           32         0.156250
#                 28                           40         0.075000
#                 29                           33         0.151515
#
# [88 rows x 14 columns]
